# %% [markdown]
# #Twitter

# %%
from twitter_api import *

tw = twitter_connect(TWITTER_API_KEYS)
target_followers = get_followers(tw, 'dturbay2', user_fields=['description', 'lang', 'name'])

target_followers
# Out:
# Rate limit reached. Sleeping for: 123
# {u'0x8a51': {'description': u'Software Engineer @Twitter',
#   'lang': u'en',
#   'name': u'Jay Pathak'},
#  u'98tango': {'description': u'', 'lang': u'en', 'name': u'Sumeet Lahorani'},
#  u'Aashura57744825': {'description': u'retweet and follow',
#   'lang': u'en',
#   'name': u'Beach vibes'},
#  u'Adegboyetemilo3': {'description': u'',
#   'lang': u'en',
#   'name': u'Adegboye Temiloluwa'},
#  u'AdrianaVecc': {'description': u'\u2728 artist & hacker. VR & AR. maker of @getfindit @thelgbtwhip. @meetmangrove. previously @twitter',
#   'lang': u'en',
#   'name': u'Adriana Vecchioli'},
#  u'AlexCurrimj': {'description': u'',
#   'lang': u'en',
#   'name': u'Alexander Currimjee'},
#  u'AlexandraUlmer': {'description': u'Reporter for Reuters in Venezuela. Previously in Chile & Argentina. alexandra.ulmer@tr.com, PGP 0xd234fcdfd86210f5',
#   'lang': u'en-gb',
#   'name': u'Alexandra Ulmer'},
#  u'AlfonsoCorredo2': {'description': u'',
# ...

# %% [markdown]
# # Gab.ai

# %%
from gab_api import *

session = start_session(login_payload)
user = get_user_feed('andrewanglin', session, write_path='./')

user
# Out:
#     actuser__id  actuser__is_donor  actuser__is_investor  actuser__is_private  \
# 0        130807              False                 False                False
# 1        130807              False                 False                False
# 2        130807              False                 False                False
# 3        130807              False                 False                False
# 4        130807              False                 False                False
# 5        130807              False                 False                False
# 6        130807              False                 False                False
# 7        130807              False                 False                False
# 8        130807              False                 False                False
# 9        130807              False                 False                False
# 10       130807              False                 False                False
# ...
