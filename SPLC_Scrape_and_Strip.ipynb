# %% [markdown]
# ### 1. Read in raw scraped files from directory
# ### 2. Strip HTML tags
# ### 3. Remove special characters / unicode
# #### Created by Jackie Weiser

# %%
import os, re, string
from BeautifulSoup import BeautifulSoup
from bs4 import BeautifulSoup
from bs4.element import Comment

# %%
# spacy is used for Part of Speech tagging and Named Entity Recognition
# spacy is a non-standard python library which can be installed using 'pip install spacy' from the command line
# language models can be downloaded by running 'python -m spacy download <language>' from the command line
import spacy
language = 'en'
nlp_model  = spacy.load('en')
    
def get_multilingual_entities(text):
    
    doc = nlp_model(text)
    labels = [{ent.text:ent.label_} for ent in doc.ents]

    return labels

# %%
path_to_docs = './'
output_clean = 'clean_scraped_text/clean_scraped_text.txt'

# %%
def stripTags(text):
    scripts = re.compile(r'<script.*?/script>')
    css = re.compile(r'<style.*?/style>')
    tags = re.compile(r'<.*?>')

    text = scripts.sub('', text)
    text = css.sub('', text)
    text = tags.sub('', text)

    return text

def punctuation_remove(text):
    """
    Mutates and returns text where all punctuation are replaced
    """
    chars = re.escape(string.punctuation)
    return re.sub(r'['+chars+']', ' ',text)

def doublespace_remove(text):
    return re.sub(' +',' ',text)

# %%
def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True


def text_from_html(body):
    soup = BeautifulSoup(body, 'html.parser')
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)  
    return u" ".join(t.strip() for t in visible_texts)

# %%
webfiles = [webfile for webfile in os.listdir(path_to_docs) if '.' in webfile]
htmlfiles = [{webfile:htmlfile} for htmlfile in os.listdir(path_to_docs + webfile) if htmlfile.endswith('.html') for webfile in webfiles]

# %%
characters_to_replace = ['\u']
htmldict = {}
for webfile in webfiles[0:10]:
    if not webfile in ['.gitignore','.DS_Store', '.git', '.ipynb_checkpoints','RawUrls.txt','README.md','SPLC_Strip_HTML.ipynb']:
        htmlfiles = [htmlfile for htmlfile in os.listdir(path_to_docs + webfile) if htmlfile.endswith('.html')]
        for htmlfile in htmlfiles:
            htmldict[webfile] = {}
            htmldict[webfile][htmlfile] = {}
            with open(path_to_docs + webfile + '/' + htmlfile, "r") as myfile:
                result = myfile.read()
            htmldict[webfile][htmlfile]['text'] = text_from_html(result)
            entities = get_multilingual_entities(htmldict[webfile][htmlfile]['text'])
            for char in characters_to_replace:
                htmldict[webfile][htmlfile]['text'] = htmldict[webfile][htmlfile]['text'].encode('ascii','replace').lower().replace(char," ")
            htmldict[webfile][htmlfile]['text'] = punctuation_remove(htmldict[webfile][htmlfile]['text'])
            htmldict[webfile][htmlfile]['text'] = doublespace_remove(htmldict[webfile][htmlfile]['text'])
            htmldict[webfile][htmlfile]['entities'] = entities
            with open(output_clean, "a") as myfile:
                myfile.write(str(htmldict[webfile][htmlfile]))

# %%
htmldict.keys()
# Out:
# ['americanfreepress.net',
#  'active-democracy.com',
#  'addr.ws',
#  'americanvikings.us',
#  'americanvikings.com']

# %%
htmldict['americanfreepress.net']['index.html']['entities']
# Out:
# [{u'                       ': u'GPE'},
#  {u'Terms Of Service': u'ORG'},
#  {u' ': u'NORP'},
#  {u'ABOUT  HELP  PRIVACY': u'QUANTITY'},
#  {u'POLICY       Facebook': u'ORG'},
#  {u'Twitter': u'GPE'},
#  {u'Youtube       ': u'PERSON'},
#  {u' ': u'NORP'},
#  {u'Multimedia   Radio': u'ORG'},
#  {u'Audio': u'PERSON'},
#  {u'Andrew Carrington Hitchcock AFP Show': u'PERSON'},
#  {u'Support  Store': u'ORG'},
#  {u'Subscribe': u'ORG'},
#  {u' Login           News': u'ORG'},
#  {u'Ticker       ': u'PERSON'},
#  {u'March 30, 2017': u'DATE'},
#  {u'American Free Press': u'ORG'},
#  {u'November 11, 2017': u'DATE'},
#  {u' ': u'NORP'},
#  {u'Audio': u'PERSON'},
#  {u'November 10, 2017': u'DATE'},
#  {u' That Bloodbath': u'LAW'},
#  {u'November 10, 2017': u'DATE'},
#  {u' ': u'NORP'},
#  {u'GOP': u'ORG'},
#  {u'Most Insidious Tax   Freedom': u'LAW'},
#  {u'November 10, 2017': u'DATE'},
#  {u' Globalists Seek': u'ORG'},
#  {u'November 7, 2017': u'DATE'},
#  {u' ': u'NORP'},
#  {u'Democrats': u'NORP'},
#  {u'Featured                      Audio': u'PERSON'},
#  {u'Trump Will Release JFK Documents           Politics': u'ORG'},
#  {u'Bloodbath': u'ORG'},
#  {u'GOP': u'ORG'},
#  {u'Most Insidious Tax           World     ': u'LAW'},
#  {u'Democrats': u'NORP'},
#  {u'Featured     Cleaning': u'PERSON'},
#  {u'the USS Liberty           National News     ': u'PRODUCT'},
#  {u'Watchdog Group Catches Shocking NYT Admission': u'PERSON'},
#  {u'Audio Interview': u'ORG'},
#  {u'National News      ': u'ORG'},
#  {u'Featured      ': u'PERSON'},
#  {u'Democrats': u'NORP'},
#  {u'November 7, 2017': u'DATE'},
#  {u'Hillary\xa0Clinton': u'PERSON'},
#  {u'DNC': u'ORG'},
#  {u'Trump\u2019s': u'ORG'},
#  {u'Russia': u'GPE'},
#  {u'FBI': u'ORG'},
#  {u'James Comey': u'PERSON'},
#  {u'Democrats': u'NORP'},
#  {u'November 7, 2017': u'DATE'},
#  {u' 0            Cleaning House': u'ORG'},
#  {u'November 2, 2017': u'DATE'},
#  {u' 2            ': u'ORG'},
#  {u'October 27, 2017': u'DATE'},
#  {u'3': u'CARDINAL'},
#  {u'           Homelessness': u'PERSON'},
#  {u'Create Health': u'ORG'},
#  {u'October 25, 2017': u'DATE'},
#  {u'3': u'CARDINAL'},
#  {u'World      Globalists Seek to Scuttle Brexit    ': u'EVENT'},
#  {u'November 10, 2017': u'DATE'},
#  {u'\xa0New World Order': u'ORG'},
#  {u'British': u'NORP'},
#  {u'Britain': u'GPE'},
#  {u'first': u'ORDINAL'},
#  {u'Mark Anderson': u'PERSON'},
#  {u'British': u'NORP'},
#  {u'June 23, 2016': u'DATE'},
#  {u'Globalists Seek to Scuttle Brexit': u'WORK_OF_ART'},
#  {u'November 10, 2017': u'DATE'},
#  {u'0': u'CARDINAL'},
#  {u'           ': u'GPE'},
#  {u'Print': u'GPE'},
#  {u'October 20, 2017': u'DATE'},
#  {u'0            ': u'DATE'},
#  {u'North Korea': u'GPE'},
#  {u'Nuke Threat': u'PERSON'},
#  {u'Multifold': u'PERSON'},
#  {u'September 27, 2017': u'DATE'},
#  {u'14': u'CARDINAL'},
#  {u'           ': u'GPE'},
#  {u'Iran': u'GPE'},
#  {u'September 18, 2017': u'DATE'},
#  {u'2': u'CARDINAL'},
#  {u'         ': u'PERSON'},
#  {u'Trump Will Release JFK Documents': u'ORG'},
#  {u'November 11, 2017': u'DATE'},
#  {u'Bloodbath': u'ORG'},
#  {u'November 10, 2017': u'DATE'},
#  {u' 0            ': u'ORG'},
#  {u'November 10, 2017': u'DATE'},
#  {u'November 10, 2017': u'DATE'},
#  {u'0            ': u'CARDINAL'},
#  {u'Democrats': u'NORP'},
#  {u'November 7, 2017': u'DATE'},
#  {u' 0            Cleaning House': u'ORG'},
#  {u'November 2, 2017': u'DATE'},
#  {u' 2     ': u'ORG'},
#  {u'WEEK': u'DATE'},
#  {u'ISSUE    AMERICAN FREE PRESS APPS            Bookstore   ': u'ORG'},
#  {u'the World      Bookstore': u'ORG'},
#  {u'Bohemian Grove': u'GPE'},
#  {u'Cult of Conspiracy      Bookstore': u'ORG'},
#  {u'50 Years': u'DATE'},
#  {u'the Deep State      Bookstore': u'ORG'},
#  {u'Puppet-Masters of Power': u'ORG'},
#  {u'Health   War Over Nutrition': u'EVENT'},
#  {u'Healthy Fats': u'PERSON'},
#  {u'Rages Behind the Scenes': u'ORG'},
#  {u'  Ecology': u'ORG'},
#  {u'Action, Vol': u'ORG'},
#  {u'     ': u'GPE'},
#  {u'  Hidden History        Conspiracy Buzz': u'LOC'},
#  {u'Trump Will Release JFK Documents': u'ORG'},
#  {u'November 11, 2017': u'DATE'},
#  {u'\xa0': u'ORG'},
#  {u'CIA': u'ORG'},
#  {u'FBI': u'ORG'},
#  {u'Trump': u'PERSON'},
#  {u'thousands': u'CARDINAL'},
#  {u'JFK': u'PERSON'},
#  {u'54 years': u'DATE'},
#  {u'another six-month': u'DATE'},
#  {u'Obama Refusing': u'PERSON'},
#  {u'Georgia Court': u'ORG'},
#  {u'February 4, 2012': u'DATE'},
#  {u'0': u'CARDINAL'},
#  {u'           ': u'GPE'},
#  {u'Putinism\u2019': u'ORG'},
#  {u'January 5, 2015': u'DATE'},
#  {u'3': u'CARDINAL'},
#  {u'GOP': u'ORG'},
#  {u'November 10, 2017': u'DATE'},
#  {u'the Federal Reserve': u'ORG'},
#  {u'Paul': u'PERSON'},
#  {u'Maryland': u'GPE'},
#  {u'Sheriff Vows': u'GPE'},
#  {u'Resist Tyranny': u'ORG'},
#  {u'December 31, 2016': u'DATE'},
#  {u' 1            ': u'ORG'},
#  {u'IRS': u'ORG'},
#  {u'October 5, 2013': u'DATE'},
#  {u' 0        ': u'LAW'},
#  {u'Archive': u'NORP'},
#  {u'     ': u'PERSON'},
#  {u'Radio Host': u'ORG'},
#  {u'Pete Santilli Cops Plea': u'PERSON'},
#  {u'Avoid Possible': u'PRODUCT'},
#  {u'Six-Year': u'DATE'},
#  {u'October 9, 2017': u'DATE'},
#  {u'Pete Santilli\u2019s': u'PERSON'},
#  {u'\xa0': u'ORG'},
#  {u'defendants\u2019': u'PRODUCT'},
#  {u'Bundy': u'PERSON'},
#  {u'\xa0': u'PERSON'},
#  {u'Bunkerville': u'PERSON'},
#  {u'BLM': u'PERSON'},
#  {u'Cliven Bundy': u'PERSON'},
#  {u'Russia': u'GPE'},
#  {u'China Move to Dump the Dollar': u'ORG'},
#  {u'June 14, 2017': u'DATE'},
#  {u'5': u'CARDINAL'},
#  {u'           ': u'GPE'},
#  {u'Chinese Regime-Change Plot Lead to Assassination': u'ORG'},
#  {u'March 17, 2017': u'DATE'},
#  {u'Radio & Podcast      ': u'ORG'},
#  {u'     ': u'GPE'},
#  {u'Trump Will Release JFK Documents': u'ORG'},
#  {u'November 11, 2017': u'DATE'},
#  {u'\xa0': u'ORG'},
#  {u'CIA': u'ORG'},
#  {u'FBI': u'ORG'},
#  {u'Trump': u'PERSON'},
#  {u'thousands': u'CARDINAL'},
#  {u'JFK': u'PERSON'},
#  {u'54 years': u'DATE'},
#  {u'another six-month': u'DATE'},
#  {u'Victor Thorn': u'PERSON'},
#  {u'Speaks': u'PERSON'},
#  {u'August 4, 2016': u'DATE'},
#  {u'54': u'DATE'},
#  {u'Yom Kippur': u'DATE'},
#  {u'Slaughter Begin': u'PERSON'},
#  {u'September 21, 2015': u'DATE'},
#  {u'28': u'CARDINAL'},
#  {u'           AUDIO INTERVIEW & ARTICLE': u'ORG'},
#  {u'The New World Order': u'ORG'},
#  {u'October 28, 2013': u'DATE'},
#  {u'10': u'CARDINAL'},
#  {u'Audio': u'ORG'},
#  {u'Victor Thorn': u'PERSON'},
#  {u'Speaks': u'PERSON'},
#  {u'August 4, 2016': u'DATE'},
#  {u'54': u'DATE'},
#  {u'AUDIO': u'ORG'},
#  {u'INTERVIEW Dave Gahary': u'PERSON'},
#  {u'William J. \u201cBill\u201d Makufka': u'PERSON'},
#  {u'Scott': u'PERSON'},
#  {u'Victor': u'PERSON'},
#  {u'70,000': u'CARDINAL'},
#  {u'Whites Murdered': u'PERSON'},
#  {u'Modern\u2019 South Africa': u'LOC'},
#  {u'Obama': u'GPE'},
#  {u'African Legacy': u'PERSON'},
#  {u'July 26, 2015': u'DATE'},
#  {u'172': u'CARDINAL'},
#  {u'           ': u'GPE'},
#  {u'AFP Clinton': u'PERSON'},
#  {u'Found Dead': u'PERSON'},
#  {u'August 1, 2016  ': u'DATE'},
#  {u'157': u'CARDINAL'},
#  {u'Only 35 Years': u'DATE'},
#  {u'December 21, 2014': u'DATE'},
#  {u'94': u'CARDINAL'},
#  {u'24 Hours': u'TIME'},
#  {u'Archive': u'NORP'},
#  {u'     ': u'PERSON'},
#  {u'70,000': u'CARDINAL'},
#  {u'Whites': u'PERSON'},
#  {u'Modern\u2019 South Africa': u'LOC'},
#  {u'Obama': u'GPE'},
#  {u'African Legacy': u'PERSON'},
#  {u'July 26, 2015': u'DATE'},
#  {u'172     ': u'DATE'},
#  {u'Paul Fromm': u'PERSON'},
#  {u'Nelson Mandela': u'PERSON'},
#  {u'African National Congress': u'ORG'},
#  {u'ANC': u'ORG'},
#  {u'South Africa': u'GPE'},
#  {u'more than 70,000': u'CARDINAL'},
#  {u'70,000': u'CARDINAL'},
#  {u'Whites Murdered': u'PERSON'},
#  {u'Modern\u2019 South Africa': u'LOC'},
#  {u'Obama': u'GPE'},
#  {u'African Legacy': u'PERSON'},
#  {u'July 26, 2015': u'DATE'},
#  {u'172': u'CARDINAL'},
#  {u'           ': u'GPE'},
#  {u'AFP Clinton': u'PERSON'},
#  {u'Found Dead': u'PERSON'},
#  {u'August 1, 2016  ': u'DATE'},
#  {u'157': u'CARDINAL'},
#  {u'Only 35 Years': u'DATE'},
#  {u'December 21, 2014': u'DATE'},
#  {u'94': u'CARDINAL'},
#  {u'the Poison Papers': u'ORG'},
#  {u'August 25, 2017': u'DATE'},
#  {u'0     ': u'CARDINAL'},
#  {u'Poison Papers': u'WORK_OF_ART'},
#  {u'decades': u'DATE'},
#  {u'\xa0': u'ORG'},
#  {u'\xa0': u'CARDINAL'},
#  {u'70,000': u'CARDINAL'},
#  {u'Whites Murdered': u'PERSON'},
#  {u'Modern\u2019 South Africa': u'LOC'},
#  {u'Obama': u'GPE'},
#  {u'African Legacy': u'PERSON'},
#  {u'July 26, 2015': u'DATE'},
#  {u'172': u'CARDINAL'},
#  {u'           ': u'GPE'},
#  {u'AFP Clinton': u'PERSON'},
#  {u'Found Dead': u'PERSON'},
#  {u'August 1, 2016  ': u'DATE'},
#  {u'157': u'CARDINAL'},
#  {u'Only 35 Years': u'DATE'},
#  {u'December 21, 2014': u'DATE'},
#  {u'94': u'CARDINAL'},
#  {u'           Edgar Steele': u'PERSON'},
#  {u'First Amendment Martyr, Dies in Prison': u'WORK_OF_ART'},
#  {u'Mysterious Circumstances': u'PERSON'},
#  {u'September 5, 2014': u'DATE'},
#  {u'72': u'CARDINAL'},
#  {u'     Hidden History': u'PERSON'},
#  {u'March 12, 2017': u'DATE'},
#  {u'An Expos\xe9': u'PERSON'},
#  {u'Modern Crimes, Conspiracies': u'ORG'},
#  {u'Cover-Ups': u'ORG'},
#  {u'American Politics': u'ORG'},
#  {u'U.S.': u'GPE'},
#  {u'American': u'NORP'},
#  {u'March 18, 2017': u'DATE'},
#  {u'           ': u'GPE'},
#  {u'Puppet-Masters of Power': u'ORG'},
#  {u'March 12, 2017': u'DATE'},
#  {u'Healthy Fats': u'PERSON'},
#  {u'Rages Behind the Scenes': u'ORG'},
#  {u'May 16, 2017': u'DATE'},
#  {u'           ': u'GPE'},
#  {u'The New World Order in Action, Vol': u'ORG'},
#  {u'1': u'CARDINAL'},
#  {u'March 18, 2017': u'DATE'},
#  {u'Archive': u'NORP'},
#  {u'     ': u'PERSON'},
#  {u'Us': u'GPE'},
#  {u'March 29, 2015': u'DATE'},
#  {u'Americas': u'LOC'},
#  {u'Indians': u'NORP'},
#  {u'AFP': u'GPE'},
#  {u'Americas': u'LOC'},
#  {u'\u2008': u'ORG'},
#  {u'June 2, 2015': u'DATE'},
#  {u'0            ': u'CARDINAL'},
#  {u'The Trans-Pacific Partnership': u'ORG'},
#  {u'Steroids': u'NORP'},
#  {u'July 4, 2015': u'DATE'},
#  {u'4': u'CARDINAL'},
#  {u'           ': u'GPE'},
#  {u'NSA': u'ORG'},
#  {u'Israel': u'GPE'},
#  {u'June 27, 2013': u'DATE'},
#  {u'0            ': u'DATE'},
#  {u'Down': u'PERSON'},
#  {u'Tubes': u'PERSON'},
#  {u'Israel': u'GPE'},
#  {u'Fraud': u'PERSON'},
#  {u'December 19, 2012  1                      ': u'DATE'},
#  {u'         Categories   Alternative Health': u'ORG'},
#  {u'Archive': u'NORP'},
#  {u'Audio': u'PERSON'},
#  {u'Featured   ': u'PERSON'},
#  {u'Mideast': u'LOC'},
#  {u'  National News   Police State   ': u'EVENT'},
#  {u'Trump Will Release JFK Documents': u'ORG'},
#  {u'Bloodbath': u'ORG'},
#  {u'GOP': u'ORG'},
#  {u'Democrats': u'NORP'},
#  {u'Dossier       ': u'ORG'},
#  {u'the USS Liberty Mark Anderson': u'PRODUCT'},
#  {u'Rhode Island Tackles': u'ORG'},
#  {u'Geoengineering\u2019': u'ORG'},
#  {u'Homelessness': u'PERSON'},
#  {u'Cleaning House': u'ORG'},
#  {u'       Home': u'PERSON'},
#  {u'ADVERTISE  HELP  ': u'QUANTITY'},
#  {u'PRIVACY': u'LOC'},
#  {u'POLICY  TERMS': u'NORP'},
#  {u'      Copyright': u'PERSON'},
#  {u'2017': u'DATE'},
#  {u'American Free Press': u'ORG'},
#  {u'                           ': u'PERSON'}]

# %%
htmldict['americanfreepress.net']['index.html']['text']
# Out:
# ' terms of service about help privacy policy facebook twitter youtube search for home multimedia radio video audio the andrew carrington hitchcock afp show archives support store subscribe about login news ticker march 30 2017 american free press is under attack national news november 11 2017 trump will release jfk documents audio november 10 2017 that bloodbath in the old dominion politics november 10 2017 gop tax plan increases the most insidious tax freedom november 10 2017 globalists seek to scuttle brexit world november 7 2017 democrats behind fake news dossier featured audio trump will release jfk documents politics that bloodbath in the old dominion freedom gop tax plan increases the most insidious tax world globalists seek to scuttle brexit featured democrats behind fake news dossier featured cleaning house conspiracy buzz rhode island tackles geoengineering audio homelessness infectious diseases combine to create health disaster audio top tier treason and the uss liberty national news media watchdog group catches shocking nyt admission on tape audio interview https youtu be aphayocfxeo national news featured democrats behind fake news dossier november 7 2017 0 the hillary clinton campaign and the dnc have been tied to the bogus report on trump s deep compromising ties to russia which even former fbi director james comey called salacious and unverified that was released before democrats behind fake news dossier november 7 2017 0 cleaning house november 2 2017 2 rhode island tackles geoengineering october 27 2017 3 homelessness infectious diseases combine to create health disaster october 25 2017 3 world news world globalists seek to scuttle brexit november 10 2017 0 the new world order elite just won t let the british put britain first by mark anderson the british brexit vote cast june 23 2016 provided a clear indication of the populist revolt that s been simmering for globalists seek to scuttle brexit november 10 2017 0 two lost thorn books back in print october 20 2017 0 north korea nuke threat is multifold september 27 2017 14 killing iran nuke deal dangerous september 18 2017 2 what s happening now trump will release jfk documents november 11 2017 0 that bloodbath in the old dominion november 10 2017 0 gop tax plan increases the most insidious tax november 10 2017 0 globalists seek to scuttle brexit november 10 2017 0 democrats behind fake news dossier november 7 2017 0 cleaning house november 2 2017 2 this week s issue american free press apps bookstore isis is us bookstore the controllers secret rulers of the world bookstore bohemian grove cult of conspiracy bookstore jfk 9 11 50 years of the deep state bookstore the bilderbergers puppet masters of power alternative health war over nutrition healthy fats quietly rages behind the scenes as americans health continues to decline bookstore ecology ideology and power bookstore the new world order in action vol 1 bookstore hidden history conspiracy buzz audio trump will release jfk documents november 11 2017 0 the cia and fbi are worried about president trump s release of thousands of jfk assassination files apparently 54 years has not allowed them enough time to review the documents so they ve asked him for another six month obama refusing to face accusers in georgia court february 4 2012 0 putinism is nationalism january 5 2015 3 freedom freedom gop tax plan increases the most insidious tax november 10 2017 0 appointing a former investment banker to chair the federal reserve will have much longer lasting impact than any tax reform plan but adopting the chained consumer price index will increase the inflation tax dr paul maryland sheriff vows to resist tyranny december 31 2016 1 irs guilty october 5 2013 0 police state archive radio host pete santilli cops plea to avoid possible six year sentence october 9 2017 6 internet radio host pete santilli s surprising plea bargain could impact the other defendants cases in the ongoing bundy proceedings given his agreement with ...
