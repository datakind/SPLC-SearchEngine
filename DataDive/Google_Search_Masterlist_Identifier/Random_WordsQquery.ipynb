# %%
# Moby Dick words from: https://github.com/dwyl/english-words
# Random words from https://www.randomlists.com/random-words

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tldextract
from google import google
from collections import Counter
from urlparse import urlparse

# %matplotlib inline

# %%
def search(query, master_list, pages = 2): 
    # Getting search results
    links = []
    query = query
    num_page = pages
    search_results = google.search(query, num_page)
    for term in search_results:
        links.append(term.link)

    # Getting domain of the links
    root = []
    for term in search_results:
        extracted = tldextract.extract(term.link)
        root.append("{}.{}".format(extracted.domain, extracted.suffix))

    # Checking which are in masterlist
    res = []
    in_list = []
    for site in root:
        in_list.append('No')
        extracted = tldextract.extract(site)
        if "{}.{}".format(extracted.domain, extracted.suffix) in ['google.com', 'facebook.com']:
            pass
        else:
            if "{}.{}".format(extracted.domain, extracted.suffix) in '.'.join(master_list):
                res.append("{}.{}".format(extracted.domain, extracted.suffix))
                in_list = in_list[:-1]
                in_list.append('Yes')     
    print "Query: {} Links Found: {}".format(query, Counter(res))

    # Returning consolidated dataframe
    search_term = [query] * len(search_results)
    domain = root
    rank = list(np.arange(len(search_results)) + 1)

    columns = {'Query': search_term, 'Results': links, 'Page Domain': root, 
               'Rank': rank, "In Master List": in_list}
    results = pd.DataFrame(columns)
    results = results[[u'Query', u'Results', u'Page Domain', u'Rank', u'In Master List']]

    return results

# %%
query_list = ['place',
'auspicious',
'awesome',
'axiomatic',
'stop',
'notebook',
'onerous'
]

# %%
master = pd.read_csv('starting dataset(s)/HateDomainMasterList_Clean.csv')

# %%
master_list = list(master['Website'])
master_list = cleanedList = [x for x in master_list if str(x) != 'nan']

# %%
consolidated = pd.DataFrame()
for q in query_list:
    results = search(q, master_list, pages = 2)
    consolidated = pd.concat([consolidated, results])
print "\n Consolidated count:", Counter(consolidated[consolidated['In Master List'] == 'Yes']['Page Domain'])
consolidated
# Out:
# Query: place Links Found: Counter()
# Query: auspicious Links Found: Counter()
# Query: awesome Links Found: Counter()
# Query: axiomatic Links Found: Counter()
# Query: stop Links Found: Counter()
# Query: notebook Links Found: Counter()
# Query: onerous Links Found: Counter()
#
#  Consolidated count: Counter()
#          Query                                            Results  \
# 0        place             http://www.dictionary.com/browse/place
# 1        place   https://www.merriam-webster.com/dictionary/place
# 2        place              http://www.thesaurus.com/browse/place
# 3        place             https://www.childrensplace.com/us/home
# 4        place               https://en.wiktionary.org/wiki/place
# 5        place            https://www.thefreedictionary.com/place
# 6        place                    https://www.reddit.com/r/place/
# 7        place                https://en.wikipedia.org/wiki/Place
# 8        place  https://developers.google.com/android/referenc...
# 9        place           https://www.stayaka.com/aka-sutton-place
# 10       place                        http://www.thisisplace.org/
# 11       place                            http://schema.org/Place
# 12       place                   https://www.facebook.com/places/
# 13       place       https://developers.facebook.com/docs/places/
# 14       place  https://www.nytimes.com/interactive/2017/11/10...
# 15       place                        http://pulse.media.mit.edu/
# 16       place                      https://www.wdl.org/en/place/
# 17       place  https://www.tripadvisorsupport.com/hc/en-us/ar...
# 0   auspicious        http://www.dictionary.com/browse/auspicious
# 1   auspicious  https://www.merriam-webster.com/dictionary/aus...
# 2   auspicious  https://www.merriam-webster.com/thesaurus/ausp...
# 3   auspicious         http://www.thesaurus.com/browse/auspicious
# 4   auspicious   https://www.vocabulary.com/dictionary/auspicious
# 5   auspicious  https://en.oxforddictionaries.com/definition/a...
# 6   auspicious          https://en.wiktionary.org/wiki/auspicious
# 7   auspicious         https://www.etymonline.com/word/auspicious
# 8   auspicious       https://www.thefreedictionary.com/auspicious
# 9   auspicious           https://en.wikipedia.org/wiki/Auspicious
# 10  auspicious  https://dictionary.cambridge.org/us/dictionary...
# 11  auspicious  https://www.collinsdictionary.com/us/dictionar...
# ..         ...                                                ...
# 8     notebook         https://www.rottentomatoes.com/m/notebook/
# 9     notebook  https://education.smarttech.com/products/notebook
# 10    notebook              https://www.erincondren.com/notebooks
# 11    notebook          https://www.gearbest.com/laptops-c_11964/
# 12    notebook  https://www.cdw.com/shop/search/hubs/Computers...
# 13    notebook                     https://society6.com/notebooks
# 14    notebook    http://nicholassparks.com/stories/the-notebook/
# 15    notebook                          https://mubi.com/notebook
# 16    notebook          http://www.dictionary.com/browse/notebook
# 17    notebook  https://help.evernote.com/hc/en-us/articles/20...
# 0      onerous           http://www.dictionary.com/browse/onerous
# 1      onerous  https://www.merriam-webster.com/dictionary/one...
# 2      onerous            http://www.thesaurus.com/browse/onerous
# 3      onerous      https://www.vocabulary.com/dictionary/onerous
# 4      onerous  https://en.oxforddictionaries.com/definition/o...
# 5      onerous  https://dictionary.cambridge.org/us/dictionary...
# 6      onerous             https://en.wiktionary.org/wiki/onerous
# 7      onerous  https://www.collinsdictionary.com/us/dictionar...
# 8      onerous          https://www.thefreedictionary.com/onerous
# 9      onerous              http://www.yourdictionary.com/onerous
# 10     onerous            https://www.etymonline.com/word/onerous
# 11     onerous              http://www.yourdictionary.com/onerous
# 12     onerous  https://www.collinsdictionary.com/us/dictionar...
# 13     onerous  http://www.learnersdictionary.com/definition/o...
# 14     onerous     http://www.mnemonicdictionary.com/word/onerous
# 15     onerous     https://www.ldoceonline.com/dictionary/onerous
# 16     onerous    http://www.wordreference.com/definition/onerous
# 17     onerous  https://www.oxfordlearnersdictionaries.com/us/...
# 18     onerous  http://www.businessdictionary.com/definition/o...
# 19     onerous      https://dict.leo.org/englisch-deutsch/onerous
#
#                        Page Domain  Rank In Master List
# 0                   dictionary.com     1             No
# 1              merriam-webster.com     2             No
# 2                    thesaurus.com     3             No
# 3               childrensplace.com     4             No
# 4                   wiktionary.org     5             No
# 5            thefreedictionary.com     6             No
# 6                       reddit.com     7             No
# 7                    wikipedia.org     8             No
# 8                       google.com     9             No
# 9                      stayaka.com    10             No
# 10                 thisisplace.org    11             No
# 11                      schema.org    12             No
# 12                    facebook.com    13             No
# 13                    facebook.com    14             No
# 14                     nytimes.com    15             No
# 15                         mit.edu    16             No
# 16                         wdl.org    17             No
# 17          tripadvisorsupport.com    18             No
# 0                   dictionary.com     1             No
# 1              merriam-webster.com     2             No
# 2              merriam-webster.com     3             No
# 3                    thesaurus.com     4             No
# 4                   vocabulary.com     5             No
# 5           oxforddictionaries.com     6             No
# 6                   wiktionary.org     7             No
# 7                   etymonline.com     8             No
# 8            thefreedictionary.com     9             No
# 9                    wikipedia.org    10             No
# 10                   cambridge.org    11             No
# 11           collinsdictionary.com    12             No
# ..                             ...   ...            ...
# 8               rottentomatoes.com     9             No
# 9                    smarttech.com    10             No
# 10                 erincondren.com    11             No
# 11                    gearbest.com    12             No
# 12                         cdw.com    13             No
# 13                    society6.com    14             No
# 14              nicholassparks.com    15             No
# 15                        mubi.com    16             No
# 16                  dictionary.com    17             No
# 17                    evernote.com    18             No
# 0                   dictionary.com     1             No
# 1              merriam-webster.com     2             No
# 2                    thesaurus.com     3             No
# 3                   vocabulary.com     4             No
# 4           oxforddictionaries.com     5             No
# 5                    cambridge.org     6             No
# 6                   wiktionary.org     7             No
# 7            collinsdictionary.com     8             No
# 8            thefreedictionary.com     9             No
# 9               yourdictionary.com    10             No
# 10                  etymonline.com    11             No
# 11              yourdictionary.com    12             No
# 12           collinsdictionary.com    13             No
# 13          learnersdictionary.com    14             No
# 14          mnemonicdictionary.com    15             No
# 15                 ldoceonline.com    16             No
# 16               wordreference.com    17             No
# 17  oxfordlearnersdictionaries.com    18             No
# 18          businessdictionary.com    19             No
# 19                         leo.org    20             No
#
# [134 rows x 5 columns]
